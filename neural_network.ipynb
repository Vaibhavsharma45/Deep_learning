# %%
 #Question 6: Write a Python program to implement a single-layer perceptron from scratch using NumPy to solve the logical AND gate.
 #Answer:

import numpy as np

# AND gate dataset
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

y = np.array([0, 0, 0, 1])

# Initialize weights and bias
weights = np.zeros(X.shape[1])
bias = 0
learning_rate = 0.1
epochs = 10

# Step activation function
def step_function(x):
    return 1 if x >= 0 else 0

# Training the perceptron
for epoch in range(epochs):
    print(f"Epoch {epoch + 1}")
    for i in range(len(X)):
        linear_output = np.dot(X[i], weights) + bias
        y_pred = step_function(linear_output)

        error = y[i] - y_pred

        # Update rule
        weights += learning_rate * error * X[i]
        bias += learning_rate * error

        print(f"Input: {X[i]}, Predicted: {y_pred}, Actual: {y[i]}")

# Testing
print("\nFinal Weights:", weights)
print("Final Bias:", bias)

print("\nTesting AND Gate:")
for i in range(len(X)):
    result = step_function(np.dot(X[i], weights) + bias)
    print(f"{X[i]} -> {result}")
# Out:
# Epoch 1
# Input: [0 0], Predicted: 1, Actual: 0
# Input: [0 1], Predicted: 0, Actual: 0
# Input: [1 0], Predicted: 0, Actual: 0
# Input: [1 1], Predicted: 0, Actual: 1
# Epoch 2
# Input: [0 0], Predicted: 1, Actual: 0
# Input: [0 1], Predicted: 1, Actual: 0
# Input: [1 0], Predicted: 0, Actual: 0
# Input: [1 1], Predicted: 0, Actual: 1
# Epoch 3
# Input: [0 0], Predicted: 0, Actual: 0
# Input: [0 1], Predicted: 1, Actual: 0
# Input: [1 0], Predicted: 1, Actual: 0
# Input: [1 1], Predicted: 0, Actual: 1
# Epoch 4
# Input: [0 0], Predicted: 0, Actual: 0
# Input: [0 1], Predicted: 0, Actual: 0
# Input: [1 0], Predicted: 0, Actual: 0
# Input: [1 1], Predicted: 1, Actual: 1
# Epoch 5
# Input: [0 0], Predicted: 0, Actual: 0
# Input: [0 1], Predicted: 0, Actual: 0
# Input: [1 0], Predicted: 0, Actual: 0
# Input: [1 1], Predicted: 1, Actual: 1
# Epoch 6
# Input: [0 0], Predicted: 0, Actual: 0
# Input: [0 1], Predicted: 0, Actual: 0
# Input: [1 0], Predicted: 0, Actual: 0
# ...

# %%
# Question 7: Implement and visualize Sigmoid, ReLU, and Tanh activation functions using Matplotlib. 
# Answer:
import numpy as np
import matplotlib.pyplot as plt

# Input range
x = np.linspace(-10, 10, 400)

# Activation functions
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def relu(x):
    return np.maximum(0, x)

def tanh(x):
    return np.tanh(x)

# Plotting
plt.figure(figsize=(8, 5))

plt.plot(x, sigmoid(x), label="Sigmoid")
plt.plot(x, relu(x), label="ReLU")
plt.plot(x, tanh(x), label="Tanh")

plt.xlabel("Input")
plt.ylabel("Output")
plt.title("Activation Functions")
plt.legend()
plt.grid(True)

plt.show()

# %%
# Question 8: Use Keras to build and train a simple multilayer neural network on the MNIST digits dataset. Print the training accuracy. 
# Answer:
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# Load MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalize data
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Build the model
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    X_train,
    y_train,
    epochs=5,
    batch_size=32,
    verbose=1
)

# Print training accuracy
train_accuracy = history.history['accuracy'][-1]
print("Training Accuracy:", train_accuracy)
# Out:
# ...
# c:\Users\vaibh\OneDrive\Documents\Python\assignments\.venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# c:\Users\vaibh\OneDrive\Documents\Python\assignments\.venv\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9289 - loss: 0.2397
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9689 - loss: 0.1019
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9790 - loss: 0.0693
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9827 - loss: 0.0544
# ...

# %%
# Question 9: Visualize the loss and accuracy curves for a neural network model trained on the Fashion MNIST dataset. Interpret the training behavior.
# Answer:
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# Load dataset
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# Normalize data
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Build model
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train model
history = model.fit(
    X_train,
    y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)

# Plot Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()
plt.grid(True)
plt.show()

# Plot Loss
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 3us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 7s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8190 - loss: 0.5110 - val_accuracy: 0.8454 - val_loss: 0.4274
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.8631 - loss: 0.3746 - val_accuracy: 0.8658 - val_loss: 0.3759
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.8766 - loss: 0.3388 - val_accuracy: 0.8655 - val_loss: 0.3685
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.8835 - loss: 0.3179 - val_accuracy: 0.8726 - val_loss: 0.3567
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.8891 - loss: 0.2963 - val_accuracy: 0.8783 - val_loss: 0.3378
# Epoch 6/10
# ...

# %%
# Question 10: You are working on a project for a bank that wants to automatically detect fraudulent transactions. The dataset is large, imbalanced, and contains structured features like transaction amount, merchant ID, and customer location. The goal is to classify each transaction as fraudulent or legitimate. 
# Explain your real-time data science workflow: 
# ● How would you design a deep learning model (perceptron or multilayer NN)? ● Which activation function and loss function would you use, and why? ● How would you train and evaluate the model, considering class imbalance? ● Which optimizer would be suitable, and how would you prevent overfitting? 

#Answer:
# 1. Model Design (Why Multilayer NN, not Perceptron)

# A single perceptron is too weak—it only learns linear boundaries.
# Fraud patterns are non-linear and subtle, so we use a Multilayer Neural Network (MLP).

# Model choice:
# Input layer → structured features (amount, merchant ID embeddings, location encodings)
# Hidden layers → learn complex interactions
# Output layer → binary classification (fraud / legit)

#  2. Activation & Loss Functions
# Activation function:
# ReLU in hidden layers → fast, avoids vanishing gradients
# Sigmoid in output layer → outputs probability of fraud (0–1)

# Loss function:
# Binary Cross-Entropy
# Designed for binary classification
# Penalizes confident wrong predictions heavily (important in fraud)

#  3. Training & Evaluation (Handling Imbalanced Data)

# Fraud datasets are highly imbalanced (≈ 1–2% fraud).
# Strategies used:
# Class weights → penalize fraud mistakes more

# Evaluation metrics beyond accuracy:
# Precision, Recall, F1-score
# Recall is critical → missing fraud is costly 💸

#  4. Optimizer & Overfitting Prevention

# Optimizer:
# Adam → adaptive learning rate, fast convergence on large datasets

# Overfitting control:
# Dropout layers
# Early stopping
# Validation monitoring

#Python Code (Keras – Fraud Detection Model)
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Dummy structured dataset (simulation)
X_train = np.random.rand(10000, 20)   # 20 structured features
y_train = np.random.choice([0, 1], size=(10000,), p=[0.95, 0.05])

# Class weights to handle imbalance
class_weight = {
    0: 1.0,   # legitimate
    1: 15.0   # fraud (higher penalty)
}

# Build MLP model
model = Sequential([
    Dense(64, activation='relu', input_shape=(20,)),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

# Compile model
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Early stopping
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

# Train model
history = model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=64,
    validation_split=0.2,
    class_weight=class_weight,
    callbacks=[early_stop],
    verbose=1
)

# Print final training accuracy
print("Final Training Accuracy:", history.history['accuracy'][-1])
# Out:
# Epoch 1/20
# c:\Users\vaibh\OneDrive\Documents\Python\assignments\.venv\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8030 - loss: 1.1813 - val_accuracy: 0.9150 - val_loss: 0.6296
# Epoch 2/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8503 - loss: 1.1580 - val_accuracy: 0.9475 - val_loss: 0.5810
# Epoch 3/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8780 - loss: 1.1597 - val_accuracy: 0.6680 - val_loss: 0.6696
# Epoch 4/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8395 - loss: 1.1618 - val_accuracy: 0.9290 - val_loss: 0.6159
# Epoch 5/20
# ...
